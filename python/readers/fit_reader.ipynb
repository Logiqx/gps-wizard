# %% [markdown]
# # FIT Reader - Flexible and Interoperable Data Transfer
#
# Copyright 2022 Michael George (AKA Logiqx).
#
# This file is part of [GPS Wizard](https://github.com/Logiqx/gps-wizard) and is distributed under the terms of the GNU General Public License.
#
# GPS Wizard is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version.
#
# GPS Wizard is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details.
#
# You should have received a copy of the GNU General Public License along with GPS Wizard. If not, see <https://www.gnu.org/licenses/>.

# %%
import os
import sys
import time

import fitdecode

import numpy as np

import unittest

from base_reader import BaseReader

# %% [markdown]
# ## Main Class

# %%
class FitReader(BaseReader):
    '''FIT file - Flexible and Interoperable Data Transfer'''

    def __init__(self, filename):
        '''Basic init just records the filename'''

        super().__init__(filename)

        self.frames = []


    def load(self):
        '''Load file into memory'''

        counts = \
        {
            'timestamp': 0,
            'position_lat': 0,
            'position_long': 0,
            'distance': 0,
            'altitude': 0,
            'speed': 0,
            'vertical_speed': 0,
            'enhanced_altitude': 0,
            'enhanced_speed': 0,
            'Sat': 0,
            'hdop': 0,
            'cog': 0
        }

        # COROS tracks tend to generate noisy warnings, hence the filter to ignore them!
        # UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"'
        # (local_mesg_num: 0; chunk_offset: 198); adding dummy dev data...
        with fitdecode.FitReader(self.filename, error_handling=fitdecode.ErrorHandling(0)) as fit:
            for frame in fit:
                if frame.frame_type == fitdecode.FIT_FRAME_DATA:
                    if frame.name == 'record':

                        # Only interested in records with latitude + longitude
                        if frame.has_field('position_lat') and frame.get_value('position_lat'):
                            # Store frame for later
                            self.frames.append(frame)

                            # Update field counts
                            for item in counts:
                                if frame.has_field(item) and frame.get_value(item):
                                    counts[item] += 1

                    elif frame.name in ['device_info', 'file_id']:
                        self.readHeader(frame)

        # Ensure firmware is a string with the correct number of decimals
        if 'firmware' in self.header:
            if 'manufacturer' in self.header and self.header['manufacturer'] == 'garmin':
                self.header['firmware'] = '{:0.2f}'.format(self.header['firmware'])
            else:
                self.header['firmware'] = '{}'.format(self.header['firmware'])

        if len(self.frames) > 0:
            self.consumePoints(counts)
            self.summarise()


    def readHeader(self, frame):
        '''Read header frame'''

        headerFields = {
            'device': ['product_name'],
            'firmware': ['software_version'],
            'manufacturer': ['manufacturer'],
            'product': ['product', 'garmin_product'],
            'serial': ['serial_number']
        }

        # Garmin files contain a lot of similar frames but the relevant ones all contain a serial number
        if frame.has_field('manufacturer') and frame.get_value('manufacturer') and (
                frame.get_value('manufacturer') != 'garmin' or \
                frame.has_field('serial_number') and frame.get_value('serial_number')):
            for headerField in headerFields:
                for fitField in headerFields[headerField]:
                    if frame.has_field(fitField):
                        self.header[headerField] = frame.get_value(fitField)
                        # Timex Ironman has trailing whitespace in product name
                        if isinstance(self.header[headerField], str):
                            self.header[headerField] = self.header[headerField].strip()

    def consumePoints(self, counts):
        '''Consume points - convert to standard data structure'''

        # Create new track object
        track = self.addTrack()

        # Convert timestamp from Garmin to Unix
        iterable = (frame.get_value('timestamp').timestamp() for frame in self.frames)
        track.data['ts'] = np.fromiter(iterable, np.float64)
        
        # Convert latitude from semicricles to degrees
        iterable = (np.round(frame.get_value('position_lat') * (180 / 2 ** 31), 7) for frame in self.frames)
        track.data['lat'] = np.fromiter(iterable, np.float64)
        
        # Convert longitude from semicricles to degrees
        iterable = (np.round(frame.get_value('position_long') * (180 / 2 ** 31), 7) for frame in self.frames)
        track.data['lon'] = np.fromiter(iterable, np.float64)
            
        # Copy distance, if present
        if counts['distance'] > 0:
            iterable = (0 if frame.has_field('distance') == False or frame.get_value('distance') is None \
                        else frame.get_value('distance') for frame in self.frames)
            track.data['dist'] = np.fromiter(iterable, np.float64)

        # Copy elevation, if present
        if counts['enhanced_altitude'] > 0:
            iterable = (0 if frame.has_field('enhanced_altitude') == False or frame.get_value('enhanced_altitude') is None \
                        else np.round(frame.get_value('enhanced_altitude'), 1) for frame in self.frames)
            track.data['ele'] = np.fromiter(iterable, np.float64)

        # Copy speed, if present
        iterable = (0 if frame.has_field('enhanced_speed') == False or frame.get_value('enhanced_speed') is None \
                    else frame.get_value('enhanced_speed') for frame in self.frames)
        track.data['sog'] = np.fromiter(iterable, np.float32)
            
        # Copy ROC (rate of climb), if present
        if counts['vertical_speed'] > 0:
            iterable = (0 if frame.has_field('vertical_speed') == False or frame.get_value('vertical_speed') is None \
                        else frame.get_value('vertical_speed') for frame in self.frames)
            track.data['roc'] = np.fromiter(iterable, np.float32)

        # Copy COG, if present - e.g. COROS APEX Pro / VERTIX / VERTIX 2
        if counts['cog'] > 0:
            iterable = (0 if frame.has_field('cog') == False or frame.get_value('cog') is None \
                        else frame.get_value('cog') for frame in self.frames)
            track.data['cog'] = np.fromiter(iterable, np.float32)

        # Copy satellites, if present - e.g. COROS APEX Pro / VERTIX / VERTIX 2
        if counts['Sat'] > 0:
            iterable = (0 if frame.has_field('Sat') == False or frame.get_value('Sat') is None \
                        else frame.get_value('Sat') for frame in self.frames)
            track.data['sat'] = np.fromiter(iterable, np.uint8)

        # Copy HDOP, if present - e.g. COROS APEX Pro / VERTIX / VERTIX 2
        if counts['hdop'] > 0:
            iterable = (0 if frame.has_field('hdop') == False or frame.get_value('hdop') is None \
                        else frame.get_value('hdop') for frame in self.frames)
            track.data['hdop'] = np.fromiter(iterable, np.float32)

# %% [markdown]
# ## COROS APEX Pro Tests

# %%
class TestCorosHeader(unittest.TestCase):
    '''Class to test COROS header was correctly loaded'''

    def testDevice(self):
        '''Test the device is as expected'''

        self.assertEqual(corosReader.header['device'], 'COROS APEX Pro')


    def testManufacturer(self):
        '''Test the manufacturer is as expected'''

        self.assertEqual(corosReader.header['manufacturer'], 'coros')


    def testProduct(self):
        '''Test the product is as expected'''

        self.assertEqual(corosReader.header['product'], 841)

# %%
class TestCorosData(unittest.TestCase):
    '''Class to test COROS data was correctly loaded'''

    def testNumRecords(self):
        '''Test the number of records is as expected'''

        for fieldName in corosReader.tracks[0].data:
            self.assertEqual(corosReader.tracks[0].data[fieldName].size, 3809)


    def testHdop(self):
        '''Test the horizontal dilution of precision is as expected'''

        # Note that this such be 0.7 to 1.6 but the FIT definition breaks the parsing
        self.assertEqual(corosReader.tracks[0].data['hdop'].min(), np.float32(0.7))
        self.assertEqual(corosReader.tracks[0].data['hdop'].max(), np.float32(1.6))


    def testSat(self):
        '''Test the satellite count is as expected'''

        self.assertEqual(corosReader.tracks[0].data['sat'].min(), np.uint8(0))
        self.assertEqual(corosReader.tracks[0].data['sat'].max(), np.uint8(14))


    def testTimestamp(self):
        '''Test the timestamp is as expected'''

        self.assertEqual(corosReader.tracks[0].data['ts'].min(), np.float64(1649672017.0))
        self.assertEqual(corosReader.tracks[0].data['ts'].max(), np.float64(1649677777.0))


    def testLat(self):
        '''Test the latitude is as expected'''

        self.assertEqual(corosReader.tracks[0].data['lat'].min(), np.float64(50.5705695))
        self.assertEqual(corosReader.tracks[0].data['lat'].max(), np.float64(50.5832841))


    def testLon(self):
        '''Test the longitude is as expected'''

        self.assertEqual(corosReader.tracks[0].data['lon'].min(), np.float64(-2.4620381))
        self.assertEqual(corosReader.tracks[0].data['lon'].max(), np.float64(-2.4559603))


    def testCog(self):
        '''Test the course over ground is as expected'''

        self.assertEqual(corosReader.tracks[0].data['cog'].min(), np.float32(0.0))
        self.assertEqual(corosReader.tracks[0].data['cog'].max(), np.float32(359.0))


    def testSog(self):
        '''Test the speed over ground is as expected'''

        self.assertEqual(corosReader.tracks[0].data['sog'].min(), np.float32(0.0))
        self.assertEqual(corosReader.tracks[0].data['sog'].max(), np.float32(16.872))

# %% [markdown]
# ## Garmin Fenix 3 Tests

# %%
class TestFenix3Header(unittest.TestCase):
    '''Class to test Fenix 3 header was correctly loaded'''

    def testManufacturer(self):
        '''Test the manufacturer is as expected'''

        self.assertEqual(fenix3Reader.header['manufacturer'], 'garmin')


    def testProduct(self):
        '''Test the product is as expected - derived by fitdecode'''

        self.assertEqual(fenix3Reader.header['product'], 'fenix3')


    def testSerial(self):
        '''Test the serial is as expected'''

        self.assertEqual(fenix3Reader.header['serial'], 3907780652)


    def testFirmware(self):
        '''Test the firmware is as expected'''

        self.assertEqual(fenix3Reader.header['firmware'], '8.20')

# %%
class TestFenix3Data(unittest.TestCase):
    '''Class to test Fenix 3 data was correctly loaded'''

    def testNumRecords(self):
        '''Test the number of records is as expected'''

        for fieldName in fenix3Reader.tracks[0].data:
            self.assertEqual(fenix3Reader.tracks[0].data[fieldName].size, 11604)


    def testTimestamp(self):
        '''Test the timestamp is as expected'''

        self.assertEqual(fenix3Reader.tracks[0].data['ts'].min(), np.float64(1575252722.0))
        self.assertEqual(fenix3Reader.tracks[0].data['ts'].max(), np.float64(1575264329.0))


    def testLat(self):
        '''Test the latitude is as expected'''

        self.assertEqual(fenix3Reader.tracks[0].data['lat'].min(), np.float64(-33.2587233))
        self.assertEqual(fenix3Reader.tracks[0].data['lat'].max(), np.float64(-33.2389579))


    def testLon(self):
        '''Test the longitude is as expected'''

        self.assertEqual(fenix3Reader.tracks[0].data['lon'].min(), np.float64(151.5426887))
        self.assertEqual(fenix3Reader.tracks[0].data['lon'].max(), np.float64(151.5476529))


    def testEle(self):
        '''Test the elevation is as expected'''

        self.assertEqual(fenix3Reader.tracks[0].data['ele'].min(), np.float64(159.2))
        self.assertEqual(fenix3Reader.tracks[0].data['ele'].max(), np.float64(353.8))


    def testSog(self):
        '''Test the speed over ground is as expected'''

        self.assertEqual(fenix3Reader.tracks[0].data['sog'].min(), np.float32(0.0))
        self.assertEqual(fenix3Reader.tracks[0].data['sog'].max(), np.float32(21.041))

# %% [markdown]
# ## Garmin Fenix 6 Tests

# %%
class TestFenix6Header(unittest.TestCase):
    '''Class to test Fenix 6 header was correctly loaded'''

    def testManufacturer(self):
        '''Test the manufacturer is as expected'''

        self.assertEqual(fenix6Reader.header['manufacturer'], 'garmin')


    def testProduct(self):
        '''Test the product is as expected - derived by fitdecode'''

        self.assertEqual(fenix6Reader.header['product'], 'fenix6x')


    def testSerial(self):
        '''Test the serial is as expected'''

        self.assertEqual(fenix6Reader.header['serial'], 3356094893)


    def testFirmware(self):
        '''Test the firmware is as expected'''

        self.assertEqual(fenix6Reader.header['firmware'], '20.30')

# %%
class TestFenix6Data(unittest.TestCase):
    '''Class to test Fenix 6 data was correctly loaded'''

    def testNumRecords(self):
        '''Test the number of records is as expected'''

        for fieldName in fenix6Reader.tracks[0].data:
            self.assertEqual(fenix6Reader.tracks[0].data[fieldName].size, 8520)


    def testTimestamp(self):
        '''Test the timestamp is as expected'''

        self.assertEqual(fenix6Reader.tracks[0].data['ts'].min(), np.float64(1644144393.0))
        self.assertEqual(fenix6Reader.tracks[0].data['ts'].max(), np.float64(1644152927.0))


    def testLat(self):
        '''Test the latitude is as expected'''

        self.assertEqual(fenix6Reader.tracks[0].data['lat'].min(), np.float64(53.3645866))
        self.assertEqual(fenix6Reader.tracks[0].data['lat'].max(), np.float64(53.3714789))


    def testLon(self):
        '''Test the longitude is as expected'''

        self.assertEqual(fenix6Reader.tracks[0].data['lon'].min(), np.float64(-3.1908654))
        self.assertEqual(fenix6Reader.tracks[0].data['lon'].max(), np.float64(-3.1859821))


    def testEle(self):
        '''Test the elevation is as expected'''

        self.assertEqual(fenix6Reader.tracks[0].data['ele'].min(), np.float64(-36.0))
        self.assertEqual(fenix6Reader.tracks[0].data['ele'].max(), np.float64(-3.4))


    def testSog(self):
        '''Test the speed over ground is as expected'''

        self.assertEqual(fenix6Reader.tracks[0].data['sog'].min(), np.float32(0.0))
        self.assertEqual(fenix6Reader.tracks[0].data['sog'].max(), np.float32(23.093))

# %% [markdown]
# ## Suunto Ambit 3 Tests

# %%
class TestAmbit3Header(unittest.TestCase):
    '''Class to test Ambit 3 header was correctly loaded'''

    def testManufacturer(self):
        '''Test the manufacturer is as expected'''

        self.assertEqual(ambit3Reader.header['manufacturer'], 'suunto')


    def testDevice(self):
        '''Test the device is as expected - derived by fitdecode'''

        self.assertEqual(ambit3Reader.header['device'], 'Suunto Ambit3 Sport')


    def testProduct(self):
        '''Test the product is as expected - derived by fitdecode'''

        self.assertEqual(ambit3Reader.header['product'], 23)

# %%
class TestAmbit3Data(unittest.TestCase):
    '''Class to test Ambit 3 data was correctly loaded'''

    def testNumRecords(self):
        '''Test the number of records is as expected'''

        for fieldName in ambit3Reader.tracks[0].data:
            self.assertEqual(ambit3Reader.tracks[0].data[fieldName].size, 509)


    def testTimestamp(self):
        '''Test the timestamp is as expected'''

        self.assertEqual(ambit3Reader.tracks[0].data['ts'].min(), np.float64(1627572732.0))
        self.assertEqual(ambit3Reader.tracks[0].data['ts'].max(), np.float64(1627575512.0))


    def testLat(self):
        '''Test the latitude is as expected'''

        self.assertEqual(ambit3Reader.tracks[0].data['lat'].min(), np.float64(53.6615636))
        self.assertEqual(ambit3Reader.tracks[0].data['lat'].max(), np.float64(53.6664171))


    def testLon(self):
        '''Test the longitude is as expected'''

        self.assertEqual(ambit3Reader.tracks[0].data['lon'].min(), np.float64(-1.0164487))
        self.assertEqual(ambit3Reader.tracks[0].data['lon'].max(), np.float64(-1.0130443))


    def testEle(self):
        '''Test the elevation is as expected'''

        self.assertEqual(ambit3Reader.tracks[0].data['ele'].min(), np.float64(0.0))
        self.assertEqual(ambit3Reader.tracks[0].data['ele'].max(), np.float64(15.0))


    def testSog(self):
        '''Test the speed over ground is as expected'''

        self.assertEqual(ambit3Reader.tracks[0].data['sog'].min(), np.float32(0.0))
        self.assertEqual(ambit3Reader.tracks[0].data['sog'].max(), np.float32(11.79))


    def testRoc(self):
        '''Test the rate of climb is as expected'''

        self.assertEqual(ambit3Reader.tracks[0].data['roc'].min(), np.float32(-0.16))
        self.assertEqual(ambit3Reader.tracks[0].data['roc'].max(), np.float32(0.31))

# %% [markdown]
# ## Timex Ironman Tests

# %%
class TestIronmanHeader(unittest.TestCase):
    '''Class to test Ironman header was correctly loaded'''

    def testManufacturer(self):
        '''Test the manufacturer is as expected'''

        self.assertEqual(ironmanReader.header['manufacturer'], 'timex')


    def testDevice(self):
        '''Test the device is as expected - derived by fitdecode'''

        self.assertEqual(ironmanReader.header['device'], 'Timex Ironman GPS')


    def testProduct(self):
        '''Test the product is as expected - derived by fitdecode'''

        self.assertEqual(ironmanReader.header['product'], 87)

# %%
class TestIronmanData(unittest.TestCase):
    '''Class to test Ironman data was correctly loaded'''

    def testNumRecords(self):
        '''Test the number of records is as expected'''

        for fieldName in ironmanReader.tracks[0].data:
            self.assertEqual(ironmanReader.tracks[0].data[fieldName].size, 2618)


    def testTimestamp(self):
        '''Test the timestamp is as expected'''

        self.assertEqual(ironmanReader.tracks[0].data['ts'].min(), np.float64(1651610788.0))
        self.assertEqual(ironmanReader.tracks[0].data['ts'].max(), np.float64(1651616155.0))


    def testLat(self):
        '''Test the latitude is as expected'''

        self.assertEqual(ironmanReader.tracks[0].data['lat'].min(), np.float64(46.0216641))
        self.assertEqual(ironmanReader.tracks[0].data['lat'].max(), np.float64(46.0293621))


    def testLon(self):
        '''Test the longitude is as expected'''

        self.assertEqual(ironmanReader.tracks[0].data['lon'].min(), np.float64(-118.9625573))
        self.assertEqual(ironmanReader.tracks[0].data['lon'].max(), np.float64(-118.9427841))


    def testEle(self):
        '''Test the elevation is as expected'''

        self.assertEqual(ironmanReader.tracks[0].data['ele'].min(), np.float64(100.0))
        self.assertEqual(ironmanReader.tracks[0].data['ele'].max(), np.float64(147.0))


    def testSog(self):
        '''Test the speed over ground is as expected'''

        self.assertEqual(ironmanReader.tracks[0].data['sog'].min(), np.float32(0.0))
        # TODO - fuse frames containing speed + enhanced_speed with frames containing latitude + longitude
        #self.assertEqual(ironmanReader.tracks[0].data['sog'].max(), np.float32(8.48))

# %% [markdown]
# ## Run Tests

# %%
if __name__ == '__main__':
    projdir = os.path.realpath(os.path.join(sys.path[0], "..", ".."))

    filename = os.path.join(projdir, 'sessions', '20220411', 'APEX_Pro_Speedsurfing20220411111317.fit')
    corosReader = FitReader(filename)

    filename = os.path.join(projdir, 'sessions', '20191202', '9C2D0835.fit')
    fenix3Reader = FitReader(filename)

    filename = os.path.join(projdir, 'sessions', '20220206', '8249369153_ACTIVITY.fit')
    fenix6Reader = FitReader(filename)

    filename = os.path.join(projdir, 'sessions', '20210729', '6102ee2d2cce8c64d5e98f55.fit')
    ambit3Reader = FitReader(filename)

    filename = os.path.join(projdir, 'sessions', '20220503', '134527CO.fit')
    ironmanReader = FitReader(filename)

    pc1 = time.perf_counter()
    corosReader.load()
    fenix3Reader.load()
    fenix6Reader.load()
    ambit3Reader.load()
    ironmanReader.load()
    pc2 = time.perf_counter()
    
    print("\nFIT files loaded in in %0.2f seconds" % (pc2 - pc1))
# Out:
# FIT files loaded in in 5.94 seconds

# %%
if __name__ == '__main__':
    # Determine whether session is interactive or batch to facilitate unittest.main(..., exit=testExit)
    import __main__ as main
    testExit = hasattr(main, '__file__')

    unittest.main(argv=['first-arg-is-ignored'], exit=testExit)
# Out:
# ..................................................
# ----------------------------------------------------------------------
# Ran 50 tests in 0.029s
#
# OK
