# %% [markdown]
# # WSW HDOP Check
#
# Iterate through folders, looking for possible spikes in all supported GPS file types.
#
# Copyright 2024 Michael George (AKA Logiqx).
#
# This file is part of [GPS Wizard](https://github.com/Logiqx/gps-wizard) and is distributed under the terms of the GNU General Public License.
#
# GPS Wizard is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation, either version 3 of the License, or (at your option) any later version.
#
# GPS Wizard is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details.
#
# You should have received a copy of the GNU General Public License along with GPS Wizard. If not, see <https://www.gnu.org/licenses/>.

# %% [markdown]
# ## Notes
#
# This is very crude and simply looks for Doppler speeds in excess of 30 m/s (i.e. 108 km/h or 58.32 knots).
#
# Such speeds are currently unrealistic for a windsurfer.

# %%
import os
import sys

import numpy as np

from shapely.geometry import Polygon, Point

import traceback

corePath = os.path.join('..', 'core')
if corePath not in sys.path:
    sys.path.extend([corePath])

from file_reader import getFileReader

# %% [markdown]
# ## Main Function

# %%
def runChecks():
    '''Iterate through session archive testing each GPS file'''

    rootDir = os.path.join(projdir, '..', 'wsw-data')

    errors = {}
    spikes = {}
    
    totFiles = 0
    totPoints = 0
    totDist = 0

    for root, subDirs, files in os.walk(rootDir):
        for file in files:
            ext = os.path.splitext(file)[1].lower()
            
            #if ext and ext in ['.sbn', '.sbp', '.ubx']:
            if ext and ext in ['.oao']:
                filePath = os.path.join(root, file)
                reader = getFileReader(filePath)
                try:
                    # Some legacy ESP-GPS files contain bad checksums
                    if ext == '.ubx':
                        reader.load(ignoreChecksums=True)
                    else:
                        reader.load()
                    
                    # Process all tracks within the file
                    for track in reader.tracks:
                        maxSog = 0

                        points = (np.argwhere(track.data['hdop'] > 5))
                        for i in points:
                            if track.data['fix'][i[0]] > 0 and \
                                    track.data['ehve'][i[0]] <= 1.2 * 1852 / 3600:
                                sog =  track.data['sog'][i[0]]
                                if sog > 0:
                                    print("fix={},sog={:.02f},hdop={:.02f},ehpe={:.02f},ehve={:.02f}".format(
                                        track.data['fix'][i[0]],  track.data['sog'][i[0]], track.data['hdop'][i[0]],
                                        track.data['ehpe'][i[0]],  track.data['ehve'][i[0]]))
                                    if sog > maxSog:
                                        maxSog = sog
                    
                        if maxSog > 0:
                            msg = '{:.02f},{:.02f},{:.02f}'.format(
                                maxSog, maxSog * 3600 / 1852, maxSog * 3600 / 1000)
                            spikes[filePath.replace(projdir + '/', '')] = msg
                            print('H', end='')

                        print('.', end='')
                        
                        totPoints += len(track.data['sog'])
                        totDist += track.data['sog'].sum()

                    totFiles += 1

                except Exception:
                    errors[filePath.replace(projdir + '/', '')] = traceback.format_exc()
                    print('E', end='')

    print('\nSummary: files = {}, points = {}, distance = {:,.02f} km'.format(totFiles, totPoints, totDist / 1000))

    if len(errors) > 0:
        print(os.linesep * 2 + 'Errors:')
        for error in errors:
            print(error)
            print(errors[error])

    if len(spikes) > 0:
        print(os.linesep * 2 + 'Crashes:')
        for spike in spikes:
            print(spike + ',' + spikes[spike])

# %%
if __name__ == '__main__':
    projdir = os.path.realpath(os.path.join(sys.path[0], "..", ".."))

    runChecks()
    
    print(os.linesep + 'All done!')
# Out:
# .....................................................................................
# fix=3,sog=3.21,hdop=10.52,ehpe=3.79,ehve=0.57
# H......................................................
# fix=3,sog=0.32,hdop=5.79,ehpe=33.50,ehve=0.53
#
# fix=3,sog=0.23,hdop=5.69,ehpe=5.85,ehve=0.61
#
# fix=3,sog=0.90,hdop=5.69,ehpe=5.65,ehve=0.61
#
# fix=3,sog=0.03,hdop=6.56,ehpe=21.50,ehve=0.22
#
# fix=3,sog=0.05,hdop=6.56,ehpe=21.61,ehve=0.30
# H.......................
# fix=3,sog=2.58,hdop=6.89,ehpe=12.07,ehve=0.61
#
# fix=3,sog=2.61,hdop=13.35,ehpe=11.35,ehve=0.60
#
# fix=3,sog=2.75,hdop=13.35,ehpe=11.34,ehve=0.60
#
# fix=3,sog=2.80,hdop=13.34,ehpe=11.35,ehve=0.61
#
# fix=3,sog=2.86,hdop=13.34,ehpe=11.35,ehve=0.60
#
# fix=3,sog=2.70,hdop=15.92,ehpe=10.78,ehve=0.58
#
# fix=3,sog=2.59,hdop=15.92,ehpe=10.42,ehve=0.57
#
# fix=3,sog=2.60,hdop=15.95,ehpe=9.13,ehve=0.56
#
# fix=3,sog=2.64,hdop=15.95,ehpe=8.94,ehve=0.56
#
# fix=3,sog=2.61,hdop=15.95,ehpe=8.81,ehve=0.55
#
# fix=3,sog=2.64,hdop=7.60,ehpe=8.74,ehve=0.55
#
# fix=3,sog=2.59,hdop=7.60,ehpe=8.59,ehve=0.54
#
# fix=3,sog=2.61,hdop=6.51,ehpe=8.35,ehve=0.54
#
# fix=3,sog=2.70,hdop=7.75,ehpe=8.26,ehve=0.54
#
# fix=3,sog=2.69,hdop=7.75,ehpe=8.22,ehve=0.54
#
# fix=3,sog=2.63,hdop=6.92,ehpe=8.13,ehve=0.51
#
# fix=3,sog=2.65,hdop=6.92,ehpe=8.11,ehve=0.51
#
# fix=3,sog=2.61,hdop=13.32,ehpe=7.93,ehve=0.52
#
# fix=3,sog=2.63,hdop=6.52,ehpe=7.93,ehve=0.52
#
# fix=3,sog=2.73,hdop=6.52,ehpe=7.88,ehve=0.52
#
# fix=3,sog=2.70,hdop=7.64,ehpe=7.86,ehve=0.51
#
# fix=3,sog=2.68,hdop=7.64,ehpe=7.86,ehve=0.52
#
# fix=3,sog=2.68,hdop=16.03,ehpe=7.91,ehve=0.52
#
# fix=3,sog=2.68,hdop=16.04,ehpe=7.89,ehve=0.53
#
# fix=3,sog=2.60,hdop=6.53,ehpe=7.86,ehve=0.53
#
# fix=3,sog=2.59,hdop=6.53,ehpe=7.78,ehve=0.51
#
# fix=3,sog=2.63,hdop=6.53,ehpe=7.76,ehve=0.50
#
# fix=3,sog=2.70,hdop=6.53,ehpe=7.78,ehve=0.51
#
# fix=3,sog=2.58,hdop=6.53,ehpe=7.77,ehve=0.50
#
# fix=3,sog=2.57,hdop=6.53,ehpe=7.78,ehve=0.51
#
# fix=3,sog=2.58,hdop=6.53,ehpe=7.79,ehve=0.52
#
# fix=3,sog=2.62,hdop=16.08,ehpe=7.79,ehve=0.53
#
# fix=3,sog=2.64,hdop=16.08,ehpe=7.74,ehve=0.52
#
# fix=3,sog=2.59,hdop=16.09,ehpe=7.72,ehve=0.52
#
# fix=3,sog=2.64,hdop=16.09,ehpe=7.69,ehve=0.52
#
# fix=3,sog=2.64,hdop=16.10,ehpe=7.69,ehve=0.52
#
# fix=3,sog=2.74,hdop=16.10,ehpe=7.67,ehve=0.52
#
# fix=3,sog=2.82,hdop=16.10,ehpe=7.68,ehve=0.53
#
# fix=3,sog=2.80,hdop=48.33,ehpe=7.69,ehve=0.54
#
# fix=3,sog=2.73,hdop=48.29,ehpe=7.69,ehve=0.53
#
# fix=3,sog=2.79,hdop=48.25,ehpe=7.71,ehve=0.54
#
# fix=3,sog=2.73,hdop=48.21,ehpe=7.72,ehve=0.54
#
# fix=3,sog=2.58,hdop=7.88,ehpe=7.79,ehve=0.52
#
# fix=3,sog=2.64,hdop=7.75,ehpe=7.75,ehve=0.52
#
# fix=3,sog=2.79,hdop=16.19,ehpe=7.78,ehve=0.54
#
# fix=3,sog=2.71,hdop=16.20,ehpe=7.72,ehve=0.53
#
# fix=3,sog=2.66,hdop=7.75,ehpe=7.69,ehve=0.53
#
# fix=3,sog=2.68,hdop=7.76,ehpe=7.64,ehve=0.52
#
# fix=3,sog=2.62,hdop=6.57,ehpe=7.63,ehve=0.53
#
# fix=3,sog=2.61,hdop=13.28,ehpe=7.58,ehve=0.53
#
# fix=3,sog=2.58,hdop=13.27,ehpe=7.50,ehve=0.54
#
# fix=3,sog=2.67,hdop=6.58,ehpe=7.51,ehve=0.54
#
# fix=3,sog=2.65,hdop=6.58,ehpe=7.53,ehve=0.54
#
# fix=3,sog=2.70,hdop=16.27,ehpe=7.57,ehve=0.55
#
# fix=3,sog=2.69,hdop=16.28,ehpe=7.54,ehve=0.54
#
# fix=3,sog=2.63,hdop=16.28,ehpe=7.52,ehve=0.54
#
# fix=3,sog=2.59,hdop=6.59,ehpe=7.58,ehve=0.54
#
# fix=3,sog=2.71,hdop=6.59,ehpe=7.56,ehve=0.55
#
# fix=3,sog=2.70,hdop=13.24,ehpe=7.57,ehve=0.55
#
# fix=3,sog=2.59,hdop=16.39,ehpe=9.10,ehve=0.54
#
# fix=3,sog=2.85,hdop=7.88,ehpe=9.05,ehve=0.56
#
# fix=3,sog=2.84,hdop=7.88,ehpe=9.04,ehve=0.55
#
# fix=3,sog=2.79,hdop=13.23,ehpe=9.01,ehve=0.55
#
# fix=3,sog=2.86,hdop=13.23,ehpe=9.00,ehve=0.56
#
# fix=3,sog=2.88,hdop=13.23,ehpe=8.94,ehve=0.55
#
# fix=3,sog=2.81,hdop=13.23,ehpe=8.92,ehve=0.54
#
# fix=3,sog=2.78,hdop=13.23,ehpe=8.89,ehve=0.54
#
# fix=3,sog=2.71,hdop=13.23,ehpe=8.85,ehve=0.54
#
# fix=3,sog=2.69,hdop=13.23,ehpe=8.84,ehve=0.54
#
# fix=3,sog=2.64,hdop=7.90,ehpe=8.81,ehve=0.54
#
# fix=3,sog=2.59,hdop=7.90,ehpe=8.79,ehve=0.53
#
# fix=3,sog=2.58,hdop=13.22,ehpe=8.76,ehve=0.53
#
# fix=3,sog=2.62,hdop=13.22,ehpe=8.75,ehve=0.53
#
# fix=3,sog=2.66,hdop=13.22,ehpe=8.73,ehve=0.54
# H......................................
# fix=3,sog=2.70,hdop=5.65,ehpe=40.47,ehve=0.48
#
# fix=3,sog=3.07,hdop=5.64,ehpe=9.69,ehve=0.56
#
# fix=3,sog=2.98,hdop=5.64,ehpe=9.39,ehve=0.59
#
# fix=3,sog=2.59,hdop=5.64,ehpe=8.71,ehve=0.61
# H.......................................................................................................................................
# fix=3,sog=0.27,hdop=6.82,ehpe=35.02,ehve=0.57
#
# fix=3,sog=0.50,hdop=15.00,ehpe=7.65,ehve=0.59
#
# fix=3,sog=0.35,hdop=15.00,ehpe=7.71,ehve=0.55
#
# fix=3,sog=0.46,hdop=15.04,ehpe=7.76,ehve=0.60
#
# fix=3,sog=0.91,hdop=12.00,ehpe=16.41,ehve=0.62
#
# fix=3,sog=0.87,hdop=12.00,ehpe=16.44,ehve=0.55
#
# fix=3,sog=0.89,hdop=12.01,ehpe=16.47,ehve=0.53
#
# fix=3,sog=0.91,hdop=12.01,ehpe=16.51,ehve=0.52
#
# fix=3,sog=0.89,hdop=18.22,ehpe=16.60,ehve=0.52
#
# fix=3,sog=0.85,hdop=18.22,ehpe=16.69,ehve=0.52
#
# fix=3,sog=0.81,hdop=12.02,ehpe=16.78,ehve=0.51
#
# fix=3,sog=0.86,hdop=12.02,ehpe=16.87,ehve=0.55
#
# fix=3,sog=0.91,hdop=13.79,ehpe=16.97,ehve=0.59
#
# fix=3,sog=0.86,hdop=13.79,ehpe=17.06,ehve=0.58
#
# fix=3,sog=0.82,hdop=13.78,ehpe=17.16,ehve=0.57
#
# fix=3,sog=0.82,hdop=13.78,ehpe=17.26,ehve=0.57
#
# fix=3,sog=0.83,hdop=64.70,ehpe=17.36,ehve=0.58
#
# fix=3,sog=0.87,hdop=64.70,ehpe=17.47,ehve=0.61
#
# fix=3,sog=0.71,hdop=15.27,ehpe=13.08,ehve=0.62
#
# fix=3,sog=0.49,hdop=11.75,ehpe=12.81,ehve=0.60
#
# fix=3,sog=0.50,hdop=11.74,ehpe=12.84,ehve=0.60
#
# fix=3,sog=0.50,hdop=11.74,ehpe=12.87,ehve=0.59
#
# fix=3,sog=0.50,hdop=11.73,ehpe=12.90,ehve=0.59
#
# fix=3,sog=0.50,hdop=11.73,ehpe=12.93,ehve=0.59
#
# fix=3,sog=0.49,hdop=11.73,ehpe=12.97,ehve=0.59
#
# fix=3,sog=0.46,hdop=13.28,ehpe=13.00,ehve=0.59
#
# fix=3,sog=0.44,hdop=13.28,ehpe=13.05,ehve=0.60
#
# fix=3,sog=0.35,hdop=11.71,ehpe=13.09,ehve=0.61
#
# fix=3,sog=0.31,hdop=13.06,ehpe=13.17,ehve=0.61
# H..........................
# Summary: files = 361, points = 8192357, distance = 66,666.73 km
#
#
# Crashes:
# ../wsw-data/events/2023/gpslogs/20231012/VAS821STA_821_20231012_095112.oao,3.21,6.23,11.54
# ../wsw-data/events/2023/gpslogs/20231013/FUL642GEO_642_20231013_090800.oao,0.90,1.75,3.25
# ../wsw-data/events/2023/gpslogs/20231013/THO811RUS_811_20231013_083822.oao,2.88,5.60,10.37
# ../wsw-data/events/2023/gpslogs/20231010/STR807DAV_807_20231010_102320.oao,3.07,5.96,11.03
# ../wsw-data/events/2023/gpslogs/20231007/KNI841FIN_841_20231007_103000.oao,0.91,1.77,3.28
#
# All done!
